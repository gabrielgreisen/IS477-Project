# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[1]
sys.path.append(str(PROJECT_ROOT))

# %%
import pandas as pd

df_firm_years = pd.read_parquet("firm_years.parquet")
df_firm_years
